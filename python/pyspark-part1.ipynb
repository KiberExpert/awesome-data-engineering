# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

# %%
spark=SparkSession.builder.appName(name='Pyspark-First-Example').getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://dd4a827b695d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Pyspark-First-Example</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data=[(1, "Alice"), (2, "John"), (3, "Brain")]

df=spark.createDataFrame(data, ["Age", "Name"])

df.show()
# Out:
# +---+-----+
# |Age| Name|
# +---+-----+
# |  1|Alice|
# |  2| John|
# |  3|Brain|
# +---+-----+
